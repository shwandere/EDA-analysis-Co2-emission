# %%
#EDA 
#enrollment no. 24911012
#name shweta sharma

# %%
import pandas as pd 
import numpy as np 
import seaborn as sbn 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("CO2 Emissions_Canada.csv")

# %%
df.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     6282.000000  6282.000000                       6282.000000
# mean         3.161812     5.618911                         12.610220
# std          1.365201     1.846250                          3.553066
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.700000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      6282.000000                       6282.000000
# mean                          9.070583                         11.017876
# std                           2.278884                          2.946876
# ...

# %%
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
df.dtypes
# Out:
# Make                                 object
# Model                                object
# Vehicle Class                        object
# Engine Size(L)                      float64
# Cylinders                             int64
# Transmission                         object
# Fuel Type                            object
# Fuel Consumption City (L/100 km)    float64
# Fuel Consumption Hwy (L/100 km)     float64
# Fuel Consumption Comb (L/100 km)    float64
# Fuel Consumption Comb (mpg)           int64
# CO2 Emissions(g/km)                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1103

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6282 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              6282 non-null   object
#  1   Model                             6282 non-null   object
#  2   Vehicle Class                     6282 non-null   object
#  3   Engine Size(L)                    6282 non-null   float64
#  4   Cylinders                         6282 non-null   int64
#  5   Transmission                      6282 non-null   object
#  6   Fuel Type                         6282 non-null   object
#  7   Fuel Consumption City (L/100 km)  6282 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   6282 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  6282 non-null   float64
#  10  Fuel Consumption Comb (mpg)       6282 non-null   int64
# ...

# %%
df['Vehicle Class'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Make'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Fuel Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Fuel Consumption City (L/100 km)'].mean()
sbn.distplot(df['Fuel Consumption City (L/100 km)'])
#df['Fuel Consumption Hwy (L/100 km)'].plot(kind='line')
#df['Fuel Consumption Comb (L/100 km)'].plot(kind='line')
#df
#df['Fuel Consumption City (L/100 km)'].plot(kind='scatter')
# Out:
# C:\Users\HP\anaconda3\envs\py3.7.10\lib\site-packages\ipykernel_launcher.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot:xlabel='Fuel Consumption City (L/100 km)', ylabel='Density'>

# %%
sbn.distplot(df['Fuel Consumption Hwy (L/100 km)'])
# Out:
# C:\Users\HP\anaconda3\envs\py3.7.10\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='Fuel Consumption Hwy (L/100 km)', ylabel='Density'>

# %%
sbn.distplot(df['Fuel Consumption Comb (L/100 km)'])
# Out:
# C:\Users\HP\anaconda3\envs\py3.7.10\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='Fuel Consumption Comb (L/100 km)', ylabel='Density'>

# %%
#sbn.distplot(df['Cylinders'])

##it is a catergorical variable

# %%
g = df[['Fuel Consumption City (L/100 km)','Fuel Consumption Hwy (L/100 km)','Fuel Consumption Comb (L/100 km)']].plot(kind='box')
g.set_xticklabels(['Fuel Consumption City (L/100 km)','Fuel Consumption Hwy (L/100 km)','Fuel Consumption Comb (L/100 km)'],rotation=90) 
plt.show()

# %%
g = sbn.violinplot(df[['Fuel Consumption City (L/100 km)','Fuel Consumption Hwy (L/100 km)','Fuel Consumption Comb (L/100 km)']])
g.set_xticklabels(['Fuel Consumption City (L/100 km)','Fuel Consumption Hwy (L/100 km)','Fuel Consumption Comb (L/100 km)'],rotation=90) 
plt.show()

# %%
###bivariate analysis
sbn.violinplot(x='Fuel Type',y='Fuel Consumption City (L/100 km)',data=df)
# Out:
# <AxesSubplot:xlabel='Fuel Type', ylabel='Fuel Consumption City (L/100 km)'>

# %%
sbn.violinplot(x='Fuel Type',y='Fuel Consumption Hwy (L/100 km)',data=df)
# Out:
# <AxesSubplot:xlabel='Fuel Type', ylabel='Fuel Consumption Hwy (L/100 km)'>

# %%
###with fuel type D fuel consumption has more variation and max consumpytion with fuel E

# %%
sbn.violinplot(x='Cylinders',y='Fuel Consumption City (L/100 km)',data=df)
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='Fuel Consumption City (L/100 km)'>

# %%
sbn.violinplot(x='Cylinders',y='Fuel Consumption Hwy (L/100 km)',data=df)
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='Fuel Consumption Hwy (L/100 km)'>

# %%
sbn.violinplot(x='Transmission',y='Fuel Consumption City (L/100 km)',data=df)
# Out:
# <AxesSubplot:xlabel='Transmission', ylabel='Fuel Consumption City (L/100 km)'>

# %%
###highest number of consumption is from cylinder 8

# %%
sbn.boxplot(x='Fuel Type',y='CO2 Emissions(g/km)',data=df)
# Out:
# <AxesSubplot:xlabel='Fuel Type', ylabel='CO2 Emissions(g/km)'>

# %%
sbn.boxplot(x='Transmission',y='CO2 Emissions(g/km)',data=df)
# Out:
# <AxesSubplot:xlabel='Transmission', ylabel='CO2 Emissions(g/km)'>

# %%
sbn.boxplot(x='Vehicle Class',y='CO2 Emissions(g/km)',data=df)
# Out:
# <AxesSubplot:xlabel='Vehicle Class', ylabel='CO2 Emissions(g/km)'>

# %%
sbn.pairplot(data=df)

# %%
###last line is important where distribution of Co2 emission is shown wrt different parameters. 
###first of all co2 emission is normally distributed. 
###numeric numeric analysis. 
####in terms of engine size as the engine size increase co2 consumption increases linearly. 
###in terms of city highway and combined, distribution is more spread out with increase in consumption.

# %%
###bivariate plot wrt co2 of all parameters. 
###above distribution what is it telling.
###max influence factor in parameters on co2 emission.

# %%
###for cylinders we can plot line plot so that mean value can be determined for different cylinders 
sbn.catplot(y='CO2 Emissions(g/km)',x='Cylinders',data=df, hue='Cylinders',kind='point')

# %%
df['Make'].astype('str')
sbn.catplot(y='CO2 Emissions(g/km)',x='Make',data=df, hue='Make',kind='point')
#g.set_xticklabels(df['Make'].astype('str').values(),rotation=90) 
#plt.show()

# %%
sbn.catplot(y='CO2 Emissions(g/km)',x='Fuel Type',data=df, hue='Fuel Type',kind='point')

# %%
###co2 emission is max for cylinder 16

# %%
df.corr()
sbn.heatmap(df.corr(), annot = True);

# %%
###high correlation with fuel consumption in cities of co2 emission and minimum correlation with cylinders. 
###in which city there is high consumption
df.groupby('Make').mean()['Fuel Consumption City (L/100 km)'].sort_values(ascending=False)
df.groupby('Make').mean()['Fuel Consumption Hwy (L/100 km)'].sort_values(ascending=False)
####bugatti has the max fuel consumption in city or hwy
####Smart has min city fuel consumption
# Out:
# Make
# BUGATTI          16.600000
# LAMBORGHINI      13.324324
# SRT              13.000000
# ROLLS-ROYCE      12.593750
# BENTLEY          11.631429
# ASTON MARTIN     11.625641
# GMC              11.553633
# LAND ROVER       10.785526
# MASERATI         10.767308
# RAM              10.588889
# FORD             10.011265
# MERCEDES-BENZ     9.875068
# CHEVROLET         9.827184
# DODGE             9.705000
# GENESIS           9.578571
# LINCOLN           9.507407
# JAGUAR            9.424576
# JEEP              9.258000
# CADILLAC          9.222695
# PORSCHE           9.152365
# INFINITI          9.083908
# CHRYSLER          8.998437
# LEXUS             8.781395
# BMW               8.659681
# NISSAN            8.655869
# AUDI              8.645627
# BUICK             8.445652
# TOYOTA            8.440580
# ALFA ROMEO        8.184211
# VOLVO             8.157627
# ACURA             8.037255
# SUBARU            7.968908
# KIA               7.752083
# HYUNDAI           7.544022
# ...

# %%
#### max fuel consumption in fuel type E leads to max Co2 emission.
###high correlation with fuel consumption in cities of co2 emission and minimum correlation with cylinders.
####bugatti has the max fuel consumption in city or highway
####Smart has min city fuel consumption 
####maximum c02 emission is due to fuel type E in average and thats what contributes to max fuel consumption in cities. 
####A4 type transmission contributes to max fuel consumption in cities and also to max co2 consumption.
